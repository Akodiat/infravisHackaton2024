# %% [markdown]
# # Data cleaning
# We need to clean data to input in a visualization of Infravis' skills and L3 projects.

# %%
import pandas as pd

# %%
skill_data = pd.read_csv('Skills_Working_code.csv', sep=";", header=[0,1])

# %%
skill_data.columns
# Out:
# MultiIndex([(   'Unnamed: 0_level_0',             '   Human Resource'),
#             (   'Unnamed: 1_level_0',                      'Position'),
#             (   'Unnamed: 2_level_0',                '   Affiliation'),
#             (   'Unnamed: 3_level_0',                      '   Time%'),
#             (    'Development Tools',                '      Paraview'),
#             (    'Development Tools',                 '       Inwivo'),
#             (    'Development Tools',          '       Unreal Engine'),
#             (    'Development Tools',                '       Blender'),
#             (    'Development Tools',                 '       Matlab'),
#             (    'Development Tools',              '       GIS-tools'),
#             (    'Development Tools',                  '       Unity'),
#             (    'Development Tools',         '       OpenSceneGraph'),
#             (    'Development Tools',        '       Esri CityEngine'),
# ...

# %%
skill_data
# Out:
#                        Unnamed: 0_level_0 Unnamed: 1_level_0  \
#                            Human Resource           Position
# 0                           Filip Berendt             IAE100
# 1                         Björn Thuresson            Lab Mgr
# 2                       Ingemar Markström                IAE
# 3                           Tino Weinkauf           Steering
# 4                      Christopher Peters         Researcher
# ..                                    ...                ...
# 74                          Stefan Seipel                NaN
# 75  Victoria Yantseva (and staff at CDHU)                IAE
# 76                             Jens Nirme                NaN
# 77                           Nikita Singh             IAE100
# 78                                average                NaN
#
#    Unnamed: 2_level_0 Unnamed: 3_level_0 Development Tools                \
#           Affiliation              Time%          Paraview        Inwivo
# ...

# %% [markdown]
# Indexing on first index:

# %%
skill_data["Hardware"]
# Out:
#           Mobile Devices        HMD        Sensors        Desktop  \
# 0               1.000000    0.00000       1.000000        3.00000
# 1               1.000000    1.00000       1.000000        0.00000
# 2               3.000000    3.00000       3.000000        4.00000
# 3               1.000000    0.00000       0.000000        4.00000
# 4               0.000000    3.00000       3.000000        4.00000
# ..                   ...        ...            ...            ...
# 74              0.000000    3.00000       2.000000        3.00000
# 75              0.000000    0.00000       0.000000        0.00000
# 76              1.000000    4.00000       1.000000        3.00000
# 77              0.000000    0.00000       0.000000        0.00000
# 78              0.432432    0.77027       0.472973        1.27027
#
#           Workstations        Super Computer        3D printers  \
# 0             0.000000              1.000000           1.000000
# ...
